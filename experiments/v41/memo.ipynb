# %% [markdown]
# ## memo
#
# - URL: https://www.kaggle.com/code/koyamaryuji/qwen-array-task-inference/notebook?scriptVersionId=342931395
# - answer only v2
# - ood

# %%
import polars as pl
from pathlib import Path
import sys
sys.path.append(str('d:/qwen_reasoning_test/ArrayTask'))
from src.gen_task import RAW_RULES, RAW_OOD_RULES_V1
RULES = [
    {
        "id": f"{i:03d}",
        "primitives": rule,
    }
    for i, rule in enumerate(RAW_OOD_RULES_V1)
]

df = pl.read_csv(Path("debug_predictions.csv"))
df = df.sort("id")
stop = 0
for pred in df.iter_rows(named=True):
    print("###" * 50)
    print(f'Task ID: \n{pred["id"].encode().decode("unicode-escape")}')
    print("===" * 50)
    print(f'Prompt: \n{pred["raw_prompt"].encode().decode("unicode-escape")}')
    print("===" * 50)
    print(f'Raw_output: \n{pred["raw_output"]}')
    print("===" * 50)
    print(f'Target: \n{pred["target"]}')
    print("===" * 50)
    print(f'Finish: \n{pred["finish_reason"]}')
    print("===" * 50)
    print(f'tokens: \n{pred["num_tokens"]}')
    if pred["finish_reason"] == "stop":
        stop += 1

print(stop)
# Out:
# ######################################################################################################################################################
# Task ID:
# 000_0
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [1, 0, 4, 3, 3, 2, 1, 8, 1, 9]
#
# Output:
# [0, 9, 1, 0, 4, 3, 3, 2, 1, 8, 1]
#
# Example 2
#
# Input:
# [0, 0, 1, 3, 3, 8, 9, 0]
#
# Output:
# [0, 0, 0, 0, 1, 3, 3, 8, 9]
#
# Example 3
#
# Input:
# [3, 8, 6, 3, 7, 9, 4, 0, 2]
#
# Output:
# [0, 2, 3, 8, 6, 3, 7, 9, 4, 0]
#
# Example 4
#
# Input:
# [6, 5, 4, 2, 3, 5, 1, 1, 6, 1]
#
# Output:
# [0, 1, 6, 5, 4, 2, 3, 5, 1, 1, 6]
#
# Example 5
#
# Input:
# [5, 9, 4, 0, 7, 8, 1]
#
# Output:
# [0, 1, 5, 9, 4, 0, 7, 8]
#
# Query
#
# Input:
# [1, 8, 4, 9, 5, 9, 3, 1]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 1, 1, 8, 4, 9, 5, 9, 3]
# ======================================================================================================================================================
# Target:
# [0, 1, 1, 8, 4, 9, 5, 9, 3]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 32
# ######################################################################################################################################################
# Task ID:
# 000_1
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [4, 2, 7, 5, 1]
#
# Output:
# [0, 1, 4, 2, 7, 5]
#
# Example 2
#
# Input:
# [9, 7, 9, 0, 8, 6, 9, 5]
#
# Output:
# [0, 5, 9, 7, 9, 0, 8, 6, 9]
#
# Example 3
#
# Input:
# [8, 6, 6, 2, 0, 1, 1, 6, 2]
#
# Output:
# [0, 2, 8, 6, 6, 2, 0, 1, 1, 6]
#
# Example 4
#
# Input:
# [2, 8, 7, 2, 6]
#
# Output:
# [0, 6, 2, 8, 7, 2]
#
# Example 5
#
# Input:
# [8, 4, 9, 2, 6, 1, 0, 9, 0]
#
# Output:
# [0, 0, 8, 4, 9, 2, 6, 1, 0, 9]
#
# Query
#
# Input:
# [0, 2, 4, 4, 1, 8]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 8, 0, 2, 4, 4, 1]
# ======================================================================================================================================================
# Target:
# [0, 8, 0, 2, 4, 4, 1]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 26
# ######################################################################################################################################################
# Task ID:
# 000_10
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [0, 8, 7, 5, 6, 0, 2]
#
# Output:
# [0, 2, 0, 8, 7, 5, 6, 0]
#
# Example 2
#
# Input:
# [6, 2, 5, 7, 0, 0]
#
# Output:
# [0, 0, 6, 2, 5, 7, 0]
#
# Example 3
#
# Input:
# [6, 7, 0, 3, 1, 2, 2, 7, 3]
#
# Output:
# [0, 3, 6, 7, 0, 3, 1, 2, 2, 7]
#
# Example 4
#
# Input:
# [4, 7, 7, 6, 1, 0, 9, 6, 1, 9]
#
# Output:
# [0, 9, 4, 7, 7, 6, 1, 0, 9, 6, 1]
#
# Example 5
#
# Input:
# [5, 8, 2, 2, 6, 8, 8, 2]
#
# Output:
# [0, 2, 5, 8, 2, 2, 6, 8, 8]
#
# Query
#
# Input:
# [1, 5, 2, 6, 9, 6, 9]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 9, 1, 5, 2, 6, 9, 6]
# ======================================================================================================================================================
# Target:
# [0, 9, 1, 5, 2, 6, 9, 6]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 29
# ######################################################################################################################################################
# Task ID:
# 000_11
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [3, 7, 8, 7, 8, 5, 7, 0, 0]
#
# Output:
# [0, 0, 3, 7, 8, 7, 8, 5, 7, 0]
#
# Example 2
#
# Input:
# [5, 2, 4, 0, 2, 0]
#
# Output:
# [0, 0, 5, 2, 4, 0, 2]
#
# Example 3
#
# Input:
# [3, 7, 3, 3, 2, 2, 5]
#
# Output:
# [0, 5, 3, 7, 3, 3, 2, 2]
#
# Example 4
#
# Input:
# [5, 8, 6, 0, 5, 4, 2, 1, 8]
#
# Output:
# [0, 8, 5, 8, 6, 0, 5, 4, 2, 1]
#
# Example 5
#
# Input:
# [6, 7, 3, 2, 0, 7, 7, 3]
#
# Output:
# [0, 3, 6, 7, 3, 2, 0, 7, 7]
#
# Query
#
# Input:
# [9, 3, 2, 1, 0, 1, 0]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 0, 9, 3, 2, 1, 0, 1]
# ======================================================================================================================================================
# Target:
# [0, 0, 9, 3, 2, 1, 0, 1]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 29
# ######################################################################################################################################################
# Task ID:
# 000_12
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [7, 8, 4, 7, 7, 6]
#
# Output:
# [0, 6, 7, 8, 4, 7, 7]
#
# Example 2
#
# Input:
# [7, 5, 9, 6, 3, 3]
#
# Output:
# [0, 3, 7, 5, 9, 6, 3]
#
# Example 3
#
# Input:
# [7, 8, 7, 9, 1]
#
# Output:
# [0, 1, 7, 8, 7, 9]
#
# Example 4
#
# Input:
# [5, 8, 4, 6, 4, 8, 2, 1, 4]
#
# Output:
# [0, 4, 5, 8, 4, 6, 4, 8, 2, 1]
#
# Example 5
#
# Input:
# [7, 9, 0, 6, 0, 5, 4]
#
# Output:
# [0, 4, 7, 9, 0, 6, 0, 5]
#
# Query
#
# Input:
# [3, 0, 2, 2, 6]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 6, 3, 0, 2, 2]
# ======================================================================================================================================================
# Target:
# [0, 6, 3, 0, 2, 2]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 23
# ######################################################################################################################################################
# Task ID:
# 000_13
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [3, 2, 4, 1, 2]
#
# Output:
# [0, 2, 3, 2, 4, 1]
#
# Example 2
#
# Input:
# [1, 5, 7, 8, 6, 6, 8]
#
# Output:
# [0, 8, 1, 5, 7, 8, 6, 6]
#
# Example 3
#
# Input:
# [5, 6, 8, 0, 4, 0, 3, 8]
#
# Output:
# [0, 8, 5, 6, 8, 0, 4, 0, 3]
#
# Example 4
#
# Input:
# [0, 9, 7, 3, 0, 6, 3, 1, 8, 6]
#
# Output:
# [0, 6, 0, 9, 7, 3, 0, 6, 3, 1, 8]
#
# Example 5
#
# Input:
# [3, 3, 6, 2, 4, 5]
#
# Output:
# [0, 5, 3, 3, 6, 2, 4]
#
# Query
#
# Input:
# [1, 6, 4, 5, 5]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 5, 1, 6, 4, 5]
# ======================================================================================================================================================
# Target:
# [0, 5, 1, 6, 4, 5]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 23
# ######################################################################################################################################################
# Task ID:
# 000_14
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [0, 7, 8, 4, 8, 6, 3, 1, 5]
#
# Output:
# [0, 5, 0, 7, 8, 4, 8, 6, 3, 1]
#
# Example 2
#
# Input:
# [1, 5, 4, 9, 3, 0, 9, 3, 0]
#
# Output:
# [0, 0, 1, 5, 4, 9, 3, 0, 9, 3]
#
# Example 3
#
# Input:
# [8, 2, 6, 0, 2, 6, 3, 2, 1]
#
# Output:
# [0, 1, 8, 2, 6, 0, 2, 6, 3, 2]
#
# Example 4
#
# Input:
# [3, 8, 3, 7, 2, 6, 2, 1, 3]
#
# Output:
# [0, 3, 3, 8, 3, 7, 2, 6, 2, 1]
#
# Example 5
#
# Input:
# [2, 3, 2, 2, 8, 7, 5, 0, 0]
#
# Output:
# [0, 0, 2, 3, 2, 2, 8, 7, 5, 0]
#
# Query
#
# Input:
# [5, 0, 9, 0, 8, 8, 1, 9, 7]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 7, 5, 0, 9, 0, 8, 8, 1, 9]
# ======================================================================================================================================================
# Target:
# [0, 7, 5, 0, 9, 0, 8, 8, 1, 9]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 35
# ######################################################################################################################################################
# Task ID:
# 000_2
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [8, 8, 1, 2, 6, 3, 4, 0]
#
# Output:
# [0, 0, 8, 8, 1, 2, 6, 3, 4]
#
# Example 2
#
# Input:
# [1, 9, 0, 1, 2, 8]
#
# Output:
# [0, 8, 1, 9, 0, 1, 2]
#
# Example 3
#
# Input:
# [4, 6, 9, 6, 5, 5, 1, 5, 4, 9]
#
# Output:
# [0, 9, 4, 6, 9, 6, 5, 5, 1, 5, 4]
#
# Example 4
#
# Input:
# [1, 8, 1, 9, 1, 4]
#
# Output:
# [0, 4, 1, 8, 1, 9, 1]
#
# Example 5
#
# Input:
# [1, 4, 0, 5, 6, 1, 7]
#
# Output:
# [0, 7, 1, 4, 0, 5, 6, 1]
#
# Query
#
# Input:
# [3, 3, 2, 4, 3, 0, 0, 6]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 6, 3, 3, 2, 4, 3, 0, 0]
# ======================================================================================================================================================
# Target:
# [0, 6, 3, 3, 2, 4, 3, 0, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 32
# ######################################################################################################################################################
# Task ID:
# 000_3
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [6, 7, 4, 1, 4, 5, 0]
#
# Output:
# [0, 0, 6, 7, 4, 1, 4, 5]
#
# Example 2
#
# Input:
# [7, 0, 1, 4, 1]
#
# Output:
# [0, 1, 7, 0, 1, 4]
#
# Example 3
#
# Input:
# [0, 9, 1, 2, 4, 2, 3]
#
# Output:
# [0, 3, 0, 9, 1, 2, 4, 2]
#
# Example 4
#
# Input:
# [6, 1, 9, 6, 2, 0, 0, 2, 5, 4]
#
# Output:
# [0, 4, 6, 1, 9, 6, 2, 0, 0, 2, 5]
#
# Example 5
#
# Input:
# [5, 1, 6, 1, 0, 5, 5]
#
# Output:
# [0, 5, 5, 1, 6, 1, 0, 5]
#
# Query
#
# Input:
# [8, 8, 9, 4, 9, 0, 7, 5]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 5, 8, 8, 9, 4, 9, 0, 7]
# ======================================================================================================================================================
# Target:
# [0, 5, 8, 8, 9, 4, 9, 0, 7]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 32
# ######################################################################################################################################################
# Task ID:
# 000_4
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [6, 0, 9, 9, 3]
#
# Output:
# [0, 3, 6, 0, 9, 9]
#
# Example 2
#
# Input:
# [8, 2, 9, 8, 0, 0, 1, 5, 0, 0]
#
# Output:
# [0, 0, 8, 2, 9, 8, 0, 0, 1, 5, 0]
#
# Example 3
#
# Input:
# [8, 4, 8, 5, 1, 6]
#
# Output:
# [0, 6, 8, 4, 8, 5, 1]
#
# Example 4
#
# Input:
# [7, 5, 2, 7, 7, 1, 7, 8, 9, 1]
#
# Output:
# [0, 1, 7, 5, 2, 7, 7, 1, 7, 8, 9]
#
# Example 5
#
# Input:
# [3, 5, 8, 7, 4, 2, 1, 9]
#
# Output:
# [0, 9, 3, 5, 8, 7, 4, 2, 1]
#
# Query
#
# Input:
# [1, 9, 5, 7, 6, 2, 6]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 6, 1, 9, 5, 7, 6, 2]
# ======================================================================================================================================================
# Target:
# [0, 6, 1, 9, 5, 7, 6, 2]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 29
# ######################################################################################################################################################
# Task ID:
# 000_5
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [1, 6, 8, 7, 9, 5, 4]
#
# Output:
# [0, 4, 1, 6, 8, 7, 9, 5]
#
# Example 2
#
# Input:
# [6, 6, 9, 0, 6, 0, 1, 0, 4]
#
# Output:
# [0, 4, 6, 6, 9, 0, 6, 0, 1, 0]
#
# Example 3
#
# Input:
# [8, 0, 5, 9, 6, 3, 3, 8]
#
# Output:
# [0, 8, 8, 0, 5, 9, 6, 3, 3]
#
# Example 4
#
# Input:
# [5, 7, 3, 0, 8, 5, 5, 9, 5]
#
# Output:
# [0, 5, 5, 7, 3, 0, 8, 5, 5, 9]
#
# Example 5
#
# Input:
# [9, 3, 3, 0, 2, 5, 1, 5, 9]
#
# Output:
# [0, 9, 9, 3, 3, 0, 2, 5, 1, 5]
#
# Query
#
# Input:
# [8, 8, 4, 1, 3, 5, 3, 7]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 7, 8, 8, 4, 1, 3, 5, 3]
# ======================================================================================================================================================
# Target:
# [0, 7, 8, 8, 4, 1, 3, 5, 3]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 32
# ######################################################################################################################################################
# Task ID:
# 000_6
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [5, 2, 8, 8, 4, 8, 3, 6, 2]
#
# Output:
# [0, 2, 5, 2, 8, 8, 4, 8, 3, 6]
#
# Example 2
#
# Input:
# [1, 7, 3, 3, 8, 8]
#
# Output:
# [0, 8, 1, 7, 3, 3, 8]
#
# Example 3
#
# Input:
# [2, 7, 3, 0, 1, 6, 1, 2, 7]
#
# Output:
# [0, 7, 2, 7, 3, 0, 1, 6, 1, 2]
#
# Example 4
#
# Input:
# [2, 2, 0, 8, 4, 5, 5, 1, 3, 4]
#
# Output:
# [0, 4, 2, 2, 0, 8, 4, 5, 5, 1, 3]
#
# Example 5
#
# Input:
# [0, 9, 4, 2, 5, 6, 2]
#
# Output:
# [0, 2, 0, 9, 4, 2, 5, 6]
#
# Query
#
# Input:
# [6, 9, 4, 0, 5, 1]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 1, 6, 9, 4, 0, 5]
# ======================================================================================================================================================
# Target:
# [0, 1, 6, 9, 4, 0, 5]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 26
# ######################################################################################################################################################
# Task ID:
# 000_7
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [5, 6, 1, 5, 8]
#
# Output:
# [0, 8, 5, 6, 1, 5]
#
# Example 2
#
# Input:
# [0, 0, 4, 2, 7, 0, 8, 8, 3]
#
# Output:
# [0, 3, 0, 0, 4, 2, 7, 0, 8, 8]
#
# Example 3
#
# Input:
# [4, 9, 5, 6, 0, 3, 2, 1, 6]
#
# Output:
# [0, 6, 4, 9, 5, 6, 0, 3, 2, 1]
#
# Example 4
#
# Input:
# [6, 5, 5, 4, 6, 9, 9, 0, 6, 8]
#
# Output:
# [0, 8, 6, 5, 5, 4, 6, 9, 9, 0, 6]
#
# Example 5
#
# Input:
# [3, 1, 9, 4, 8, 9, 8, 5, 2]
#
# Output:
# [0, 2, 3, 1, 9, 4, 8, 9, 8, 5]
#
# Query
#
# Input:
# [3, 5, 4, 9, 6, 9, 7, 7]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 7, 3, 5, 4, 9, 6, 9, 7]
# ======================================================================================================================================================
# Target:
# [0, 7, 3, 5, 4, 9, 6, 9, 7]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 32
# ######################################################################################################################################################
# Task ID:
# 000_8
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [4, 5, 3, 7, 5, 1, 8, 5]
#
# Output:
# [0, 5, 4, 5, 3, 7, 5, 1, 8]
#
# Example 2
#
# Input:
# [8, 1, 2, 5, 1, 5]
#
# Output:
# [0, 5, 8, 1, 2, 5, 1]
#
# Example 3
#
# Input:
# [3, 3, 1, 5, 9, 9, 6]
#
# Output:
# [0, 6, 3, 3, 1, 5, 9, 9]
#
# Example 4
#
# Input:
# [1, 1, 9, 5, 6, 0, 3, 5, 4, 6]
#
# Output:
# [0, 6, 1, 1, 9, 5, 6, 0, 3, 5, 4]
#
# Example 5
#
# Input:
# [1, 3, 7, 4, 9, 7, 2, 4, 9, 3]
#
# Output:
# [0, 3, 1, 3, 7, 4, 9, 7, 2, 4, 9]
#
# Query
#
# Input:
# [9, 1, 6, 9, 1, 8, 7, 6, 8]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 8, 9, 1, 6, 9, 1, 8, 7, 6]
# ======================================================================================================================================================
# Target:
# [0, 8, 9, 1, 6, 9, 1, 8, 7, 6]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 35
# ######################################################################################################################################################
# Task ID:
# 000_9
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [8, 8, 2, 3, 3, 8]
#
# Output:
# [0, 8, 8, 8, 2, 3, 3]
#
# Example 2
#
# Input:
# [6, 8, 7, 8, 8, 5, 9]
#
# Output:
# [0, 9, 6, 8, 7, 8, 8, 5]
#
# Example 3
#
# Input:
# [5, 6, 4, 6, 0, 1, 0, 8, 4, 0]
#
# Output:
# [0, 0, 5, 6, 4, 6, 0, 1, 0, 8, 4]
#
# Example 4
#
# Input:
# [2, 5, 9, 4, 5, 7, 3, 0]
#
# Output:
# [0, 0, 2, 5, 9, 4, 5, 7, 3]
#
# Example 5
#
# Input:
# [2, 7, 0, 0, 1, 9, 1, 2]
#
# Output:
# [0, 2, 2, 7, 0, 0, 1, 9, 1]
#
# Query
#
# Input:
# [7, 0, 6, 6, 3, 5, 1, 7, 8]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 8, 7, 0, 6, 6, 3, 5, 1, 7]
# ======================================================================================================================================================
# Target:
# [0, 8, 7, 0, 6, 6, 3, 5, 1, 7]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 35
# ######################################################################################################################################################
# Task ID:
# 001_0
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [5, 9, 9, 0, 3]
#
# Output:
# [3, 5, 9, 9, 0, 0]
#
# Example 2
#
# Input:
# [5, 7, 4, 6, 6, 0, 2, 8, 9]
#
# Output:
# [9, 5, 7, 4, 6, 6, 0, 2, 8, 0]
#
# Example 3
#
# Input:
# [6, 6, 1, 9, 7, 8, 4]
#
# Output:
# [4, 6, 6, 1, 9, 7, 8, 0]
#
# Example 4
#
# Input:
# [9, 2, 9, 2, 2, 6, 8, 2, 9, 6]
#
# Output:
# [6, 9, 2, 9, 2, 2, 6, 8, 2, 9, 0]
#
# Example 5
#
# Input:
# [2, 9, 6, 5, 9, 8, 8, 3, 3]
#
# Output:
# [3, 2, 9, 6, 5, 9, 8, 8, 3, 0]
#
# Query
#
# Input:
# [6, 3, 6, 7, 0, 7, 7]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [7, 6, 3, 6, 7, 0, 7, 0]
# ======================================================================================================================================================
# Target:
# [7, 6, 3, 6, 7, 0, 7, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 29
# ######################################################################################################################################################
# Task ID:
# 001_1
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [3, 3, 3, 0, 3, 7, 6, 5, 4]
#
# Output:
# [4, 3, 3, 3, 0, 3, 7, 6, 5, 0]
#
# Example 2
#
# Input:
# [7, 9, 6, 4, 9, 1, 0]
#
# Output:
# [0, 7, 9, 6, 4, 9, 1, 0]
#
# Example 3
#
# Input:
# [3, 7, 1, 7, 8, 6, 5, 0]
#
# Output:
# [0, 3, 7, 1, 7, 8, 6, 5, 0]
#
# Example 4
#
# Input:
# [2, 4, 0, 2, 4]
#
# Output:
# [4, 2, 4, 0, 2, 0]
#
# Example 5
#
# Input:
# [2, 9, 9, 3, 1, 2, 3]
#
# Output:
# [3, 2, 9, 9, 3, 1, 2, 0]
#
# Query
#
# Input:
# [2, 2, 2, 3, 0, 4, 4, 1]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [1, 2, 2, 2, 3, 0, 4, 4, 0]
# ======================================================================================================================================================
# Target:
# [1, 2, 2, 2, 3, 0, 4, 4, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 32
# ######################################################################################################################################################
# Task ID:
# 001_10
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [1, 6, 7, 6, 4]
#
# Output:
# [4, 1, 6, 7, 6, 0]
#
# Example 2
#
# Input:
# [6, 7, 9, 4, 3, 0, 2, 4, 0]
#
# Output:
# [0, 6, 7, 9, 4, 3, 0, 2, 4, 0]
#
# Example 3
#
# Input:
# [7, 2, 1, 1, 7, 4]
#
# Output:
# [4, 7, 2, 1, 1, 7, 0]
#
# Example 4
#
# Input:
# [6, 9, 0, 6, 8, 2]
#
# Output:
# [2, 6, 9, 0, 6, 8, 0]
#
# Example 5
#
# Input:
# [5, 8, 0, 7, 3, 6]
#
# Output:
# [6, 5, 8, 0, 7, 3, 0]
#
# Query
#
# Input:
# [5, 2, 6, 8, 0]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 5, 2, 6, 8, 0]
# ======================================================================================================================================================
# Target:
# [0, 5, 2, 6, 8, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 23
# ######################################################################################################################################################
# Task ID:
# 001_11
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [7, 8, 1, 9, 9, 3, 6, 7, 4, 5]
#
# Output:
# [5, 7, 8, 1, 9, 9, 3, 6, 7, 4, 0]
#
# Example 2
#
# Input:
# [8, 5, 2, 8, 1, 0, 8, 7]
#
# Output:
# [7, 8, 5, 2, 8, 1, 0, 8, 0]
#
# Example 3
#
# Input:
# [5, 0, 1, 9, 2]
#
# Output:
# [2, 5, 0, 1, 9, 0]
#
# Example 4
#
# Input:
# [3, 0, 8, 6, 7, 8]
#
# Output:
# [8, 3, 0, 8, 6, 7, 0]
#
# Example 5
#
# Input:
# [8, 2, 8, 0, 9, 2, 9, 9]
#
# Output:
# [9, 8, 2, 8, 0, 9, 2, 9, 0]
#
# Query
#
# Input:
# [2, 1, 0, 7, 6, 9, 4]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [4, 2, 1, 0, 7, 6, 9, 0]
# ======================================================================================================================================================
# Target:
# [4, 2, 1, 0, 7, 6, 9, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 29
# ######################################################################################################################################################
# Task ID:
# 001_12
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [0, 1, 2, 1, 9, 5, 5, 8, 6, 7]
#
# Output:
# [7, 0, 1, 2, 1, 9, 5, 5, 8, 6, 0]
#
# Example 2
#
# Input:
# [9, 7, 8, 5, 8, 8, 7, 2]
#
# Output:
# [2, 9, 7, 8, 5, 8, 8, 7, 0]
#
# Example 3
#
# Input:
# [6, 1, 6, 4, 2, 3, 2, 4]
#
# Output:
# [4, 6, 1, 6, 4, 2, 3, 2, 0]
#
# Example 4
#
# Input:
# [8, 3, 1, 1, 6, 9]
#
# Output:
# [9, 8, 3, 1, 1, 6, 0]
#
# Example 5
#
# Input:
# [1, 4, 9, 5, 0, 1, 1, 3, 0, 2]
#
# Output:
# [2, 1, 4, 9, 5, 0, 1, 1, 3, 0, 0]
#
# Query
#
# Input:
# [3, 4, 2, 7, 1, 5]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [5, 3, 4, 2, 7, 1, 0]
# ======================================================================================================================================================
# Target:
# [5, 3, 4, 2, 7, 1, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 26
# ######################################################################################################################################################
# Task ID:
# 001_13
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [4, 7, 7, 2, 5]
#
# Output:
# [5, 4, 7, 7, 2, 0]
#
# Example 2
#
# Input:
# [2, 9, 3, 6, 6]
#
# Output:
# [6, 2, 9, 3, 6, 0]
#
# Example 3
#
# Input:
# [6, 1, 8, 5, 4, 6]
#
# Output:
# [6, 6, 1, 8, 5, 4, 0]
#
# Example 4
#
# Input:
# [1, 1, 0, 7, 5, 4, 2, 0]
#
# Output:
# [0, 1, 1, 0, 7, 5, 4, 2, 0]
#
# Example 5
#
# Input:
# [7, 1, 7, 1, 2, 5, 8]
#
# Output:
# [8, 7, 1, 7, 1, 2, 5, 0]
#
# Query
#
# Input:
# [9, 1, 0, 8, 6, 0]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 9, 1, 0, 8, 6, 0]
# ======================================================================================================================================================
# Target:
# [0, 9, 1, 0, 8, 6, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 26
# ######################################################################################################################################################
# Task ID:
# 001_14
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [8, 9, 0, 4, 2, 3, 4]
#
# Output:
# [4, 8, 9, 0, 4, 2, 3, 0]
#
# Example 2
#
# Input:
# [3, 8, 0, 9, 3]
#
# Output:
# [3, 3, 8, 0, 9, 0]
#
# Example 3
#
# Input:
# [0, 8, 5, 7, 2, 5, 2, 0, 5]
#
# Output:
# [5, 0, 8, 5, 7, 2, 5, 2, 0, 0]
#
# Example 4
#
# Input:
# [0, 6, 9, 3, 2, 5, 6, 7, 1]
#
# Output:
# [1, 0, 6, 9, 3, 2, 5, 6, 7, 0]
#
# Example 5
#
# Input:
# [0, 3, 9, 2, 2, 3, 8, 5, 4, 9]
#
# Output:
# [9, 0, 3, 9, 2, 2, 3, 8, 5, 4, 0]
#
# Query
#
# Input:
# [4, 5, 3, 6, 0]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [0, 4, 5, 3, 6, 0]
# ======================================================================================================================================================
# Target:
# [0, 4, 5, 3, 6, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 23
# ######################################################################################################################################################
# Task ID:
# 001_2
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [1, 7, 0, 2, 4, 0]
#
# Output:
# [0, 1, 7, 0, 2, 4, 0]
#
# Example 2
#
# Input:
# [9, 0, 7, 6, 7, 8, 4, 2, 9, 5]
#
# Output:
# [5, 9, 0, 7, 6, 7, 8, 4, 2, 9, 0]
#
# Example 3
#
# Input:
# [2, 8, 1, 1, 5, 0, 5, 4, 1, 0]
#
# Output:
# [0, 2, 8, 1, 1, 5, 0, 5, 4, 1, 0]
#
# Example 4
#
# Input:
# [1, 9, 9, 1, 4, 4]
#
# Output:
# [4, 1, 9, 9, 1, 4, 0]
#
# Example 5
#
# Input:
# [9, 9, 1, 5, 9]
#
# Output:
# [9, 9, 9, 1, 5, 0]
#
# Query
#
# Input:
# [6, 0, 1, 7, 4, 8]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [8, 6, 0, 1, 7, 4, 0]
# ======================================================================================================================================================
# Target:
# [8, 6, 0, 1, 7, 4, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 26
# ######################################################################################################################################################
# Task ID:
# 001_3
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [4, 9, 2, 4, 3, 7, 7]
#
# Output:
# [7, 4, 9, 2, 4, 3, 7, 0]
#
# Example 2
#
# Input:
# [0, 1, 2, 2, 6, 0, 3]
#
# Output:
# [3, 0, 1, 2, 2, 6, 0, 0]
#
# Example 3
#
# Input:
# [0, 6, 2, 2, 4, 9, 2, 8, 9, 8]
#
# Output:
# [8, 0, 6, 2, 2, 4, 9, 2, 8, 9, 0]
#
# Example 4
#
# Input:
# [0, 9, 9, 1, 4, 2, 0, 9, 3]
#
# Output:
# [3, 0, 9, 9, 1, 4, 2, 0, 9, 0]
#
# Example 5
#
# Input:
# [3, 8, 4, 1, 3, 2, 4]
#
# Output:
# [4, 3, 8, 4, 1, 3, 2, 0]
#
# Query
#
# Input:
# [3, 9, 1, 8, 5, 7]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [7, 3, 9, 1, 8, 5, 0]
# ======================================================================================================================================================
# Target:
# [7, 3, 9, 1, 8, 5, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 26
# ######################################################################################################################################################
# Task ID:
# 001_4
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [2, 8, 3, 5, 4, 5, 0, 7]
#
# Output:
# [7, 2, 8, 3, 5, 4, 5, 0, 0]
#
# Example 2
#
# Input:
# [5, 1, 6, 7, 5, 2, 5]
#
# Output:
# [5, 5, 1, 6, 7, 5, 2, 0]
#
# Example 3
#
# Input:
# [0, 8, 1, 2, 5, 0, 6, 2, 2, 6]
#
# Output:
# [6, 0, 8, 1, 2, 5, 0, 6, 2, 2, 0]
#
# Example 4
#
# Input:
# [4, 5, 7, 5, 9, 5, 2]
#
# Output:
# [2, 4, 5, 7, 5, 9, 5, 0]
#
# Example 5
#
# Input:
# [9, 4, 6, 6, 3, 2, 2, 0, 8, 5]
#
# Output:
# [5, 9, 4, 6, 6, 3, 2, 2, 0, 8, 0]
#
# Query
#
# Input:
# [0, 8, 6, 1, 4, 0, 6, 2]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [2, 0, 8, 6, 1, 4, 0, 6, 0]
# ======================================================================================================================================================
# Target:
# [2, 0, 8, 6, 1, 4, 0, 6, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 32
# ######################################################################################################################################################
# Task ID:
# 001_5
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [2, 1, 3, 7, 4, 5, 2, 8, 2]
#
# Output:
# [2, 2, 1, 3, 7, 4, 5, 2, 8, 0]
#
# Example 2
#
# Input:
# [0, 4, 2, 1, 0, 7]
#
# Output:
# [7, 0, 4, 2, 1, 0, 0]
#
# Example 3
#
# Input:
# [8, 0, 5, 9, 2, 3, 1, 5]
#
# Output:
# [5, 8, 0, 5, 9, 2, 3, 1, 0]
#
# Example 4
#
# Input:
# [7, 9, 0, 9, 6, 4, 5, 5, 7]
#
# Output:
# [7, 7, 9, 0, 9, 6, 4, 5, 5, 0]
#
# Example 5
#
# Input:
# [4, 4, 9, 6, 3]
#
# Output:
# [3, 4, 4, 9, 6, 0]
#
# Query
#
# Input:
# [9, 4, 3, 2, 9, 0, 9, 9, 9, 3]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [3, 9, 4, 3, 2, 9, 0, 9, 9, 9, 0]
# ======================================================================================================================================================
# Target:
# [3, 9, 4, 3, 2, 9, 0, 9, 9, 9, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 38
# ######################################################################################################################################################
# Task ID:
# 001_6
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [7, 4, 4, 7, 1, 6, 1, 1]
#
# Output:
# [1, 7, 4, 4, 7, 1, 6, 1, 0]
#
# Example 2
#
# Input:
# [3, 4, 1, 4, 9, 0, 3, 2, 5, 3]
#
# Output:
# [3, 3, 4, 1, 4, 9, 0, 3, 2, 5, 0]
#
# Example 3
#
# Input:
# [9, 0, 0, 9, 2, 3, 9]
#
# Output:
# [9, 9, 0, 0, 9, 2, 3, 0]
#
# Example 4
#
# Input:
# [6, 6, 5, 7, 3, 1, 0, 0, 5]
#
# Output:
# [5, 6, 6, 5, 7, 3, 1, 0, 0, 0]
#
# Example 5
#
# Input:
# [5, 1, 0, 9, 2, 9, 0, 6, 7]
#
# Output:
# [7, 5, 1, 0, 9, 2, 9, 0, 6, 0]
#
# Query
#
# Input:
# [5, 0, 5, 0, 5]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [5, 5, 0, 5, 0, 0]
# ======================================================================================================================================================
# Target:
# [5, 5, 0, 5, 0, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 23
# ######################################################################################################################################################
# Task ID:
# 001_7
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [1, 9, 6, 8, 0, 3, 4, 3]
#
# Output:
# [3, 1, 9, 6, 8, 0, 3, 4, 0]
#
# Example 2
#
# Input:
# [2, 1, 6, 7, 3, 0, 1, 6, 0, 1]
#
# Output:
# [1, 2, 1, 6, 7, 3, 0, 1, 6, 0, 0]
#
# Example 3
#
# Input:
# [1, 9, 0, 9, 4, 3]
#
# Output:
# [3, 1, 9, 0, 9, 4, 0]
#
# Example 4
#
# Input:
# [3, 1, 0, 7, 6, 3, 4, 2, 8]
#
# Output:
# [8, 3, 1, 0, 7, 6, 3, 4, 2, 0]
#
# Example 5
#
# Input:
# [5, 8, 4, 5, 7, 8, 2, 0]
#
# Output:
# [0, 5, 8, 4, 5, 7, 8, 2, 0]
#
# Query
#
# Input:
# [3, 7, 2, 3, 3]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [3, 3, 7, 2, 3, 0]
# ======================================================================================================================================================
# Target:
# [3, 3, 7, 2, 3, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 23
# ######################################################################################################################################################
# Task ID:
# 001_8
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [4, 4, 8, 3, 7, 7, 8, 7]
#
# Output:
# [7, 4, 4, 8, 3, 7, 7, 8, 0]
#
# Example 2
#
# Input:
# [5, 6, 3, 1, 8, 7, 4, 3, 7]
#
# Output:
# [7, 5, 6, 3, 1, 8, 7, 4, 3, 0]
#
# Example 3
#
# Input:
# [0, 4, 1, 2, 8, 2, 1, 2, 5]
#
# Output:
# [5, 0, 4, 1, 2, 8, 2, 1, 2, 0]
#
# Example 4
#
# Input:
# [9, 5, 9, 3, 3, 6, 7]
#
# Output:
# [7, 9, 5, 9, 3, 3, 6, 0]
#
# ...
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 11
# ######################################################################################################################################################
# Task ID:
# 035_13
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [8, 4, 1, 4, 2, 6, 4, 4, 3]
#
# Output:
# [4, 4, 6, 4]
#
# Example 2
#
# Input:
# [3, 4, 4, 8, 5, 6, 8, 4, 2, 8]
#
# Output:
# [4, 8, 6, 4, 3]
#
# Example 3
#
# Input:
# [5, 4, 6, 5, 6, 1, 9, 9]
#
# Output:
# [4, 5, 1, 5]
#
# Example 4
#
# Input:
# [1, 2, 4, 5, 7, 4, 3, 7, 5]
#
# Output:
# [2, 5, 4, 7]
#
# Example 5
#
# Input:
# [7, 9, 1, 4, 1, 1, 6, 2, 6, 2]
#
# Output:
# [9, 4, 1, 2, 7]
#
# Query
#
# Input:
# [0, 7, 6, 9, 9, 9]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [7, 9, 0]
# ======================================================================================================================================================
# Target:
# [7, 9, 0]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 14
# ######################################################################################################################################################
# Task ID:
# 035_14
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [0, 2, 4, 4, 6, 0, 9, 6, 4, 7]
#
# Output:
# [2, 4, 0, 6, 0]
#
# Example 2
#
# Input:
# [8, 0, 4, 4, 0, 5, 9, 7, 4]
#
# Output:
# [0, 4, 5, 7]
#
# Example 3
#
# Input:
# [2, 0, 7, 0, 2, 9, 8, 3]
#
# Output:
# [0, 0, 9, 2]
#
# Example 4
#
# Input:
# [0, 5, 6, 2, 2, 0, 3, 6]
#
# Output:
# [5, 2, 0, 0]
#
# Example 5
#
# Input:
# [3, 3, 1, 4, 8, 9]
#
# Output:
# [3, 4, 3]
#
# Query
#
# Input:
# [4, 8, 1, 4, 2, 6, 3, 0, 2, 9]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [8, 4, 6, 0, 9]
# ======================================================================================================================================================
# Target:
# [8, 4, 6, 0, 4]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 20
# ######################################################################################################################################################
# Task ID:
# 035_2
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [8, 0, 5, 0, 5, 4, 4, 9, 1]
#
# Output:
# [0, 0, 4, 9]
#
# Example 2
#
# Input:
# [7, 9, 1, 7, 8, 2, 5, 4, 0, 4]
#
# Output:
# [9, 7, 2, 4, 7]
#
# Example 3
#
# Input:
# [7, 8, 1, 7, 0, 5]
#
# Output:
# [8, 7, 7]
#
# Example 4
#
# Input:
# [2, 5, 3, 1, 8, 7, 6]
#
# Output:
# [5, 1, 7]
#
# Example 5
#
# Input:
# [8, 3, 2, 1, 9, 1, 2, 5]
#
# Output:
# [3, 1, 1, 8]
#
# Query
#
# Input:
# [9, 6, 0, 4, 9, 1]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [6, 4, 9]
# ======================================================================================================================================================
# Target:
# [6, 4, 9]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 14
# ######################################################################################################################################################
# Task ID:
# 035_3
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [3, 0, 5, 0, 0]
#
# Output:
# [0, 0]
#
# Example 2
#
# Input:
# [5, 8, 9, 3, 3, 5, 5]
#
# Output:
# [8, 3, 5]
#
# Example 3
#
# Input:
# [6, 1, 5, 4, 0]
#
# Output:
# [1, 4]
#
# Example 4
#
# Input:
# [7, 5, 8, 0, 6, 9, 8, 3, 4, 9]
#
# Output:
# [5, 0, 9, 3, 7]
#
# Example 5
#
# Input:
# [9, 6, 5, 3, 2]
#
# Output:
# [6, 3]
#
# Query
#
# Input:
# [6, 4, 6, 8, 2, 5, 3]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [4, 8, 5]
# ======================================================================================================================================================
# Target:
# [4, 8, 5]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 14
# ######################################################################################################################################################
# Task ID:
# 035_4
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [4, 1, 9, 6, 0, 2]
#
# Output:
# [1, 6, 4]
#
# Example 2
#
# Input:
# [9, 2, 8, 2, 2]
#
# Output:
# [2, 2]
#
# Example 3
#
# Input:
# [8, 0, 4, 5, 1, 7, 9]
#
# Output:
# [0, 5, 7]
#
# Example 4
#
# Input:
# [9, 7, 4, 5, 0]
#
# Output:
# [7, 5]
#
# Example 5
#
# Input:
# [6, 6, 0, 0, 4]
#
# Output:
# [6, 0]
#
# Query
#
# Input:
# [7, 4, 3, 2, 2, 2, 2, 8, 7]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [4, 2, 2, 8]
# ======================================================================================================================================================
# Target:
# [4, 2, 2, 8]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 17
# ######################################################################################################################################################
# Task ID:
# 035_5
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [6, 4, 4, 9, 4, 9]
#
# Output:
# [4, 9, 6]
#
# Example 2
#
# Input:
# [1, 2, 3, 2, 2, 3, 6, 9]
#
# Output:
# [2, 2, 3, 1]
#
# Example 3
#
# Input:
# [7, 6, 3, 9, 9, 8, 2]
#
# Output:
# [6, 9, 8]
#
# Example 4
#
# Input:
# [5, 3, 4, 3, 2]
#
# Output:
# [3, 3]
#
# Example 5
#
# Input:
# [1, 7, 1, 1, 5, 6, 2, 4, 4]
#
# Output:
# [7, 1, 6, 4]
#
# Query
#
# Input:
# [7, 2, 5, 4, 6, 1, 1, 6, 2, 1]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [2, 6, 1, 5, 7]
# ======================================================================================================================================================
# Target:
# [2, 4, 1, 6, 7]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 20
# ######################################################################################################################################################
# Task ID:
# 035_6
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [4, 3, 1, 6, 8, 8, 7, 2, 9, 9]
#
# Output:
# [3, 6, 8, 2, 4]
#
# Example 2
#
# Input:
# [7, 4, 6, 6, 7]
#
# Output:
# [4, 6]
#
# Example 3
#
# Input:
# [9, 7, 5, 5, 9, 8, 7]
#
# Output:
# [7, 5, 8]
#
# Example 4
#
# Input:
# [7, 5, 5, 3, 9]
#
# Output:
# [5, 3]
#
# Example 5
#
# Input:
# [0, 6, 4, 7, 5]
#
# Output:
# [6, 7]
#
# Query
#
# Input:
# [9, 5, 2, 5, 8, 0, 3, 5]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [5, 5, 0, 5]
# ======================================================================================================================================================
# Target:
# [5, 5, 0, 9]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 17
# ######################################################################################################################################################
# Task ID:
# 035_7
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [9, 8, 1, 4, 3, 6, 7]
#
# Output:
# [8, 4, 6]
#
# Example 2
#
# Input:
# [6, 0, 3, 4, 8, 0, 6, 6]
#
# Output:
# [0, 4, 0, 6]
#
# Example 3
#
# Input:
# [9, 4, 6, 5, 1, 3]
#
# Output:
# [4, 5, 9]
#
# Example 4
#
# Input:
# [2, 0, 0, 0, 0, 8, 4, 0, 2, 9]
#
# Output:
# [0, 0, 8, 0, 2]
#
# Example 5
#
# Input:
# [8, 5, 5, 8, 1, 3, 1, 4]
#
# Output:
# [5, 8, 3, 8]
#
# Query
#
# Input:
# [1, 7, 9, 6, 8, 9, 4, 1]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [7, 6, 9, 1]
# ======================================================================================================================================================
# Target:
# [7, 6, 9, 1]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 17
# ######################################################################################################################################################
# Task ID:
# 035_8
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [0, 6, 1, 6, 7, 6, 9]
#
# Output:
# [6, 6, 6]
#
# Example 2
#
# Input:
# [5, 1, 4, 7, 2, 4, 4, 9, 0, 6]
#
# Output:
# [1, 7, 4, 9, 5]
#
# Example 3
#
# Input:
# [3, 0, 3, 5, 6, 5, 3, 7, 9, 2]
#
# Output:
# [0, 5, 5, 7, 3]
#
# Example 4
#
# Input:
# [0, 1, 2, 5, 1, 3, 1, 1]
#
# Output:
# [1, 5, 3, 0]
#
# Example 5
#
# Input:
# [0, 7, 4, 2, 1, 5, 2]
#
# Output:
# [7, 2, 5]
#
# Query
#
# Input:
# [6, 1, 6, 2, 5, 2, 6]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [1, 2, 2, 6]
# ======================================================================================================================================================
# Target:
# [1, 2, 2]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 17
# ######################################################################################################################################################
# Task ID:
# 035_9
# ======================================================================================================================================================
# Prompt:
#
# Infer the transformation rule from the examples.
#
# State the rule you inferred in one short sentence.
# Then apply the rule to the Query input.
# Finally, output the complete final array.
#
# Example 1
#
# Input:
# [9, 7, 3, 0, 9, 5, 6, 8, 1, 3]
#
# Output:
# [7, 0, 5, 8, 9]
#
# Example 2
#
# Input:
# [7, 4, 2, 0, 5, 8, 4]
#
# Output:
# [4, 0, 8]
#
# Example 3
#
# Input:
# [3, 5, 6, 2, 2, 8, 7, 7, 7]
#
# Output:
# [5, 2, 8, 7]
#
# Example 4
#
# Input:
# [1, 2, 6, 4, 8, 6, 4]
#
# Output:
# [2, 4, 6]
#
# Example 5
#
# Input:
# [1, 8, 7, 7, 6, 9, 2]
#
# Output:
# [8, 7, 9]
#
# Query
#
# Input:
# [4, 6, 7, 9, 3, 0, 2, 5, 1, 5]
#
# Output:
# ======================================================================================================================================================
# Raw_output:
# <think>
#
# </think>
#
# [6, 9, 0, 5]
# ======================================================================================================================================================
# Target:
# [6, 9, 0, 5, 4]
# ======================================================================================================================================================
# Finish:
# stop
# ======================================================================================================================================================
# tokens:
# 17
# 540

# %%
import re
import ast
import polars as pl
from pathlib import Path


def extract_answer(text):
    if text is None:
        return 'NOT_FOUND'

    matches = re.findall(r'\[[^\[\]]*\]', text)
    arrays = []
    for match in matches:
        try:
            value = ast.literal_eval(match)

            if isinstance(value, list):
                arrays.append(value)

        except (ValueError, SyntaxError):
            pass

    if arrays == []:
        return 'NOT_FOUND'

    return str(arrays[-1])

df = pl.read_csv(Path("debug_predictions.csv"))

match_count = 0
match = []
miss = []
for pred in df.iter_rows(named=True):
    # print("###" * 50)
    answer = extract_answer(pred["raw_output"])
    if answer == pred["target"]:
        # print(pred["id"])
        match_count += 1
        match.append(pred["id"].split("_")[0])
    else:
        miss.append(pred["id"].split("_")[0])
        # print(pred["id"])
        # print(pred["raw_prompt"].encode().decode("unicode-escape"))
        # print(pred["target"])
print(f"len(df): {len(df)}")
print(f"match_count: {match_count}")
print(f"acc: {match_count / len(df)}")
# print(miss)
from collections import Counter


counts = Counter(miss)
match_counts = Counter(match)
# Out:
# len(df): 540
# match_count: 270
# acc: 0.5

# %% [markdown]
# # 正解

# %%
match_results = []

for rule in RULES:
    if rule["id"] in [i for i, j in match_counts.items()]:
        for i, j in match_counts.items():
            if rule["id"] == i:
                match_results.append({"task_id": i, "count": j, "rule": rule["primitives"]})
    else:
        match_results.append({"task_id": rule["id"], "count": 0, "rule": rule["primitives"]})

match_results = sorted(match_results, key=lambda x: x["task_id"], reverse=True)

for x in match_results:
    print(x)
# Out:
# {'task_id': '035', 'count': 8, 'rule': ['swap', 'take_odd_positions']}
# {'task_id': '034', 'count': 1, 'rule': ['swap', 'take_even_positions']}
# {'task_id': '033', 'count': 6, 'rule': ['swap', 'mirror']}
# {'task_id': '032', 'count': 0, 'rule': ['swap', 'pairwise_sum']}
# {'task_id': '031', 'count': 1, 'rule': ['swap', 'differences']}
# {'task_id': '030', 'count': 1, 'rule': ['swap', 'modulo']}
# {'task_id': '029', 'count': 3, 'rule': ['swap', 'add_constant']}
# {'task_id': '028', 'count': 5, 'rule': ['swap', 'multiply_constant']}
# {'task_id': '027', 'count': 15, 'rule': ['swap', 'pop_left']}
# {'task_id': '026', 'count': 11, 'rule': ['swap', 'pop_right']}
# {'task_id': '025', 'count': 13, 'rule': ['swap', 'append_zeros']}
# {'task_id': '024', 'count': 4, 'rule': ['swap', 'prepend_zeros']}
# {'task_id': '023', 'count': 9, 'rule': ['rotate_left', 'take_odd_positions']}
# {'task_id': '022', 'count': 8, 'rule': ['rotate_left', 'take_even_positions']}
# {'task_id': '021', 'count': 14, 'rule': ['rotate_left', 'mirror']}
# {'task_id': '020', 'count': 2, 'rule': ['rotate_left', 'pairwise_sum']}
# {'task_id': '019', 'count': 0, 'rule': ['rotate_left', 'differences']}
# {'task_id': '018', 'count': 0, 'rule': ['rotate_left', 'modulo']}
# {'task_id': '017', 'count': 11, 'rule': ['rotate_left', 'add_constant']}
# {'task_id': '016', 'count': 14, 'rule': ['rotate_left', 'multiply_constant']}
# {'task_id': '015', 'count': 12, 'rule': ['rotate_left', 'pop_left']}
# {'task_id': '014', 'count': 15, 'rule': ['rotate_left', 'pop_right']}
# {'task_id': '013', 'count': 15, 'rule': ['rotate_left', 'append_zeros']}
# {'task_id': '012', 'count': 15, 'rule': ['rotate_left', 'prepend_zeros']}
# {'task_id': '011', 'count': 13, 'rule': ['rotate_right', 'take_odd_positions']}
# {'task_id': '010', 'count': 0, 'rule': ['rotate_right', 'take_even_positions']}
# {'task_id': '009', 'count': 14, 'rule': ['rotate_right', 'mirror']}
# {'task_id': '008', 'count': 0, 'rule': ['rotate_right', 'pairwise_sum']}
# {'task_id': '007', 'count': 0, 'rule': ['rotate_right', 'differences']}
# {'task_id': '006', 'count': 0, 'rule': ['rotate_right', 'modulo']}
# {'task_id': '005', 'count': 0, 'rule': ['rotate_right', 'add_constant']}
# {'task_id': '004', 'count': 0, 'rule': ['rotate_right', 'multiply_constant']}
# {'task_id': '003', 'count': 15, 'rule': ['rotate_right', 'pop_left']}
# {'task_id': '002', 'count': 15, 'rule': ['rotate_right', 'pop_right']}
# {'task_id': '001', 'count': 15, 'rule': ['rotate_right', 'append_zeros']}
# {'task_id': '000', 'count': 15, 'rule': ['rotate_right', 'prepend_zeros']}

# %% [markdown]
# # 不正解

# %%
results = []
for i, j in counts.items():
    for rule in RULES:
        if rule["id"] == i:
            # print(i, j, rule)
            results.append({"task_id": i, "count": j, "rule": rule["primitives"]})

results = sorted(results, key=lambda x: x["task_id"], reverse=True)
results
# Out:
# [{'task_id': '035', 'count': 7, 'rule': ['swap', 'take_odd_positions']},
#  {'task_id': '034', 'count': 14, 'rule': ['swap', 'take_even_positions']},
#  {'task_id': '033', 'count': 9, 'rule': ['swap', 'mirror']},
#  {'task_id': '032', 'count': 15, 'rule': ['swap', 'pairwise_sum']},
#  {'task_id': '031', 'count': 14, 'rule': ['swap', 'differences']},
#  {'task_id': '030', 'count': 14, 'rule': ['swap', 'modulo']},
#  {'task_id': '029', 'count': 12, 'rule': ['swap', 'add_constant']},
#  {'task_id': '028', 'count': 10, 'rule': ['swap', 'multiply_constant']},
#  {'task_id': '026', 'count': 4, 'rule': ['swap', 'pop_right']},
#  {'task_id': '025', 'count': 2, 'rule': ['swap', 'append_zeros']},
#  {'task_id': '024', 'count': 11, 'rule': ['swap', 'prepend_zeros']},
#  {'task_id': '023', 'count': 6, 'rule': ['rotate_left', 'take_odd_positions']},
#  {'task_id': '022',
#   'count': 7,
#   'rule': ['rotate_left', 'take_even_positions']},
#  {'task_id': '021', 'count': 1, 'rule': ['rotate_left', 'mirror']},
#  {'task_id': '020', 'count': 13, 'rule': ['rotate_left', 'pairwise_sum']},
#  {'task_id': '019', 'count': 15, 'rule': ['rotate_left', 'differences']},
#  {'task_id': '018', 'count': 15, 'rule': ['rotate_left', 'modulo']},
#  {'task_id': '017', 'count': 4, 'rule': ['rotate_left', 'add_constant']},
#  {'task_id': '016', 'count': 1, 'rule': ['rotate_left', 'multiply_constant']},
#  {'task_id': '015', 'count': 3, 'rule': ['rotate_left', 'pop_left']},
#  {'task_id': '011',
#   'count': 2,
#   'rule': ['rotate_right', 'take_odd_positions']},
#  {'task_id': '010',
#   'count': 15,
#   'rule': ['rotate_right', 'take_even_positions']},
#  {'task_id': '009', 'count': 1, 'rule': ['rotate_right', 'mirror']},
#  {'task_id': '008', 'count': 15, 'rule': ['rotate_right', 'pairwise_sum']},
#  {'task_id': '007', 'count': 15, 'rule': ['rotate_right', 'differences']},
#  {'task_id': '006', 'count': 15, 'rule': ['rotate_right', 'modulo']},
#  {'task_id': '005', 'count': 15, 'rule': ['rotate_right', 'add_constant']},
#  {'task_id': '004',
#   'count': 15,
#   'rule': ['rotate_right', 'multiply_constant']}]

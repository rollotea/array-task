# %% [markdown]
# ## experiments全体のメモ
#
# - v29とそれより前のものは全部なし
#
# - v32はベースモデルで追加の学習は何もしない
#
# - v41とそれ以前も使わないと思う、v42から頑張る
#
# ### ↓こっから本番
#
# ## base_model
# - v43: v3_iid base_model
# - v44: v3_ood base_model
#
# ## answer_only_adapter
# - v46: v3_iid answer_only_adapter
# - v47: v3_ood answer_only_adapter
#
# ## state_transition_trace_adapter
# - v48: v3_iid state_transition_trace_adapter
# - v49: v3_ood_state_transition_trace_adapter

# %% [markdown]
# ## experiments全体のメモ
#
# - v29とそれより前のものは全部なし
#
# - v32はベースモデルで追加の学習は何もしない
#
# - v41とそれ以前も使わないと思う、v42から頑張る
#
# ### ↓こっから本番
#
# ## base_model
# - v43: v3_iid base_model acc: 0.4073529411764706
# - v44: v3_ood base_model acc: 0.13958333333333334
#
# - v52: v3-iid base_model 8000token acc: 0.475
#
# ## answer_only_adapter
# - v46: v3_iid answer_only_adapter acc: 0.711764705882353
# - v47: v3_ood answer_only_adapter acc: 0.41875
#
# ## state_transition_trace_adapter
# - v48: v3_iid state_transition_trace_adapter acc: 0.8058823529411765
# - v49: v3_ood_state_transition_trace_adapter acc: 0.20416666666666666
#
# ## multi_candidate_trace_adapter
# - v50: v3_iid multi_candidate_trace_adapter acc: 0.5191176470588236
# - v51: v3_ood multi_candidate_trace_adapter acc: 0.2375
